# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush-ak87/Data-Science-learn/blob/main/Ordinal_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ordinal numbering Encoding or Label Encoding

# %%
import pandas as pd
import datetime

# %%
df_base = datetime.datetime.today()
df_date_list = [df_base - datetime.timedelta(days=x) for x in range(0, 20)]
df = pd.DataFrame(df_date_list)
df.columns = ['day']
df
# Out:
#                           day
# 0  2024-02-06 16:59:24.963215
# 1  2024-02-05 16:59:24.963215
# 2  2024-02-04 16:59:24.963215
# 3  2024-02-03 16:59:24.963215
# 4  2024-02-02 16:59:24.963215
# 5  2024-02-01 16:59:24.963215
# 6  2024-01-31 16:59:24.963215
# 7  2024-01-30 16:59:24.963215
# 8  2024-01-29 16:59:24.963215
# 9  2024-01-28 16:59:24.963215
# 10 2024-01-27 16:59:24.963215
# 11 2024-01-26 16:59:24.963215
# 12 2024-01-25 16:59:24.963215
# 13 2024-01-24 16:59:24.963215
# 14 2024-01-23 16:59:24.963215
# 15 2024-01-22 16:59:24.963215
# 16 2024-01-21 16:59:24.963215
# 17 2024-01-20 16:59:24.963215
# 18 2024-01-19 16:59:24.963215
# 19 2024-01-18 16:59:24.963215

# %%
df['day_of_week'] = df['day'].dt.day_name()
df.head()
# Out:
#                          day day_of_week
# 0 2024-02-06 16:59:24.963215     Tuesday
# 1 2024-02-05 16:59:24.963215      Monday
# 2 2024-02-04 16:59:24.963215      Sunday
# 3 2024-02-03 16:59:24.963215    Saturday
# 4 2024-02-02 16:59:24.963215      Friday

# %%
weekday_map = {'Monday':1,
               'Tuesday':2,
               'Wednesday':3,
               'Thursday':4,
               'Friday':5,
               'Saturday':6,
               'Sunday':7
}

df['day_ordinal'] = df.day_of_week.map(weekday_map)
df.head(20)
# Out:
#                           day day_of_week  day_ordinal
# 0  2024-02-06 16:59:24.963215     Tuesday            2
# 1  2024-02-05 16:59:24.963215      Monday            1
# 2  2024-02-04 16:59:24.963215      Sunday            7
# 3  2024-02-03 16:59:24.963215    Saturday            6
# 4  2024-02-02 16:59:24.963215      Friday            5
# 5  2024-02-01 16:59:24.963215    Thursday            4
# 6  2024-01-31 16:59:24.963215   Wednesday            3
# 7  2024-01-30 16:59:24.963215     Tuesday            2
# 8  2024-01-29 16:59:24.963215      Monday            1
# 9  2024-01-28 16:59:24.963215      Sunday            7
# 10 2024-01-27 16:59:24.963215    Saturday            6
# 11 2024-01-26 16:59:24.963215      Friday            5
# 12 2024-01-25 16:59:24.963215    Thursday            4
# 13 2024-01-24 16:59:24.963215   Wednesday            3
# 14 2024-01-23 16:59:24.963215     Tuesday            2
# 15 2024-01-22 16:59:24.963215      Monday            1
# ...

# %% [markdown]
# [Source](https://youtu.be/fxw_Ak4t-LY?si=27jnWhF03jYUkV_X)
